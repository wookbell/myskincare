# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.corpus import stopwords

# %%
df = pd.read_excel('data/cream_sentiment_result.xlsx')

# %%
df
# Out:
#       Unnamed: 0 brand          name bottle  price_num  star  \
# 0              0   주미소  워터풀 히알루론산 크림   50g       24000  4.68
# 1              1   주미소  워터풀 히알루론산 크림   50g       24000  4.68
# 2              2   주미소  워터풀 히알루론산 크림   50g       24000  4.68
# 3              3   주미소  워터풀 히알루론산 크림   50g       24000  4.68
# 4              4   주미소  워터풀 히알루론산 크림   50g       24000  4.68
# ...          ...   ...           ...    ...        ...   ...
# 7446        7446    헤라       시그니아 크림  60ml      280000  4.12
# 7447        7447    헤라       시그니아 크림  60ml      280000  4.12
# 7448        7448    헤라       시그니아 크림  60ml      280000  4.12
# 7449        7449    헤라       시그니아 크림  60ml      280000  4.12
# 7450        7450    헤라       시그니아 크림  60ml      280000  4.12
#
#                                            product_info  \
# 0     수부지를 위한 청량수분케어- 물방울 얹은 듯 가볍게 스며드는 수분크림- 7종 히알루...
# 1     수부지를 위한 청량수분케어- 물방울 얹은 듯 가볍게 스며드는 수분크림- 7종 히알루...
# 2     수부지를 위한 청량수분케어- 물방울 얹은 듯 가볍게 스며드는 수분크림- 7종 히알루...
# ...

# %%
def tfidf_vect_func(df, target_col, target_row):

    tfidf_vect = TfidfVectorizer()
    feature_vect = tfidf_vect.fit_transform(df[target_col])

    similarity_simple_pair = cosine_similarity(feature_vect[target_row], feature_vect)
    result_list = similarity_simple_pair.tolist()[0]
    df[f'{target_col}_result'] = result_list

    return df

def count_vect_func(df,target_col, target_row):
    count_vect_category = CountVectorizer(min_df=0, ngram_range=(1,2))
    feature_vect = count_vect_category.fit_transform(df[target_col])

    similarity_simple_pair = cosine_similarity(feature_vect[target_row], feature_vect)
    result_list = similarity_simple_pair.tolist()[0]
    df[f'{target_col}_result'] = result_list

    return df

def tfidf_count_result(df,review_col,tag_col,problem,hashtag):

    df = df.append(pd.Series(),ignore_index= True)
    last_index = df.iloc[[-1]].index[0]

    df.at[last_index, review_col] = problem  #input('피부 고민을 말씀해주세요. : ')\
    df.at[last_index,tag_col] = hashtag      #input('태그를 입력해주세요 : ')

    tfidf_vect_func(df, review_col, last_index)
    count_vect_func(df, tag_col, last_index)

    return df

# %%
review = '여드름이 많고 볼쪽이 건조해요'
hashtag = '미백'

# %%
df_result = tfidf_count_result(df, 'review', 'product_type', review, hashtag)
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
df_result.sort_values(by='review_result', inplace=True, ascending=False)

# %%
df_result
# Out:
#       Unnamed: 0  brand                      name bottle  price_num  star  \
# 7451         NaN    NaN                       NaN    NaN        NaN   NaN
# 2672      2672.0  나인위시스               VB 얼티밋 톤업크림  50ml     44000.0  3.70
# 5210      5210.0   수네이처            스피루리나 리페어 아이크림  30ml     36000.0  4.00
# 2019      2019.0    블랑풀                      필터크림  40ml     19000.0  4.17
# 6406      6406.0     미샤  비타민 B12 더블하이드롭 크림 컨센트레이트  50ml     26000.0  3.73
# ...          ...    ...                       ...    ...        ...   ...
# 2497      2497.0   페리페라               밀크 블러 톤업 크림  60ml     10000.0  3.77
# 2496      2496.0   페리페라               밀크 블러 톤업 크림  60ml     10000.0  3.77
# 2495      2495.0   페리페라               밀크 블러 톤업 크림  60ml     10000.0  3.77
# 2494      2494.0   페리페라               밀크 블러 톤업 크림  60ml     10000.0  3.77
# 3726      3726.0     라헬                 나이트케어 보습젤  100g     45000.0  4.20
#
#                                            product_info  \
# ...

# %%
#부정리뷰 필터링
df_result = df_result[df_result["sentiment_judge"]==1]

# %%
df_result
# Out:
#       Unnamed: 0 brand                        name  bottle  price_num  star  \
# 6406      6406.0    미샤    비타민 B12 더블하이드롭 크림 컨센트레이트   50ml     26000.0  3.73
# 556        556.0  아이소이          모이스춰 닥터 크림 (장수진크림)   70ml     36000.0  4.37
# 7114      7114.0  이자녹스  에이지 포커스 프라임 더블 이펙트 아이포올 크림   50ml     85000.0  4.12
# 2486      2486.0    더연                    여우 미백 크림  100ml      9900.0  3.96
# 6442      6442.0   시드물                  센텔라 구스팟 크림   30ml     22800.0  4.75
# ...          ...   ...                         ...     ...        ...   ...
# 2501      2501.0  페리페라                 밀크 블러 톤업 크림   60ml     10000.0  3.77
# 2498      2498.0  페리페라                 밀크 블러 톤업 크림   60ml     10000.0  3.77
# 2497      2497.0  페리페라                 밀크 블러 톤업 크림   60ml     10000.0  3.77
# 2495      2495.0  페리페라                 밀크 블러 톤업 크림   60ml     10000.0  3.77
# 2494      2494.0  페리페라                 밀크 블러 톤업 크림   60ml     10000.0  3.77
#
# ...

# %%
#태그 가중치 포함 유사도 점수 계산
df_result['new_result'] = df_result['review_result']+(df_result['product_type_result']*0.2)
df_result
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Unnamed: 0 brand                        name  bottle  price_num  star  \
# 6406      6406.0    미샤    비타민 B12 더블하이드롭 크림 컨센트레이트   50ml     26000.0  3.73
# 556        556.0  아이소이          모이스춰 닥터 크림 (장수진크림)   70ml     36000.0  4.37
# 7114      7114.0  이자녹스  에이지 포커스 프라임 더블 이펙트 아이포올 크림   50ml     85000.0  4.12
# 2486      2486.0    더연                    여우 미백 크림  100ml      9900.0  3.96
# 6442      6442.0   시드물                  센텔라 구스팟 크림   30ml     22800.0  4.75
# ...          ...   ...                         ...     ...        ...   ...
# 2501      2501.0  페리페라                 밀크 블러 톤업 크림   60ml     10000.0  3.77
# ...

# %%
#상위20%잘라내기
df_result_review_sort = df_result.sort_values(by='review_result',ascending=False).copy()
df_result_review_sort = df_result_review_sort[1:]
df_result_num = len(df_result_review_sort)*0.2
df_result_num = int(df_result_num)
df_result = df_result_review_sort[:df_result_num]

# %%
df_result
# Out:
#       Unnamed: 0 brand                        name  bottle  price_num  star  \
# 556        556.0  아이소이          모이스춰 닥터 크림 (장수진크림)   70ml     36000.0  4.37
# 7114      7114.0  이자녹스  에이지 포커스 프라임 더블 이펙트 아이포올 크림   50ml     85000.0  4.12
# 2486      2486.0    더연                    여우 미백 크림  100ml      9900.0  3.96
# 6442      6442.0   시드물                  센텔라 구스팟 크림   30ml     22800.0  4.75
# 690        690.0    미샤           수퍼 아쿠아 울트라 히알론 크림   70ml     28000.0  4.25
# ...          ...   ...                         ...     ...        ...   ...
# 1423      1423.0   엘러브           듀얼 카밍 오일 & 바운싱 크림   50ml     73000.0  4.32
# 1412      1412.0   엘러브           듀얼 카밍 오일 & 바운싱 크림   50ml     73000.0  4.32
# 1413      1413.0   엘러브           듀얼 카밍 오일 & 바운싱 크림   50ml     73000.0  4.32
# 1414      1414.0   엘러브           듀얼 카밍 오일 & 바운싱 크림   50ml     73000.0  4.32
# 1416      1416.0   엘러브           듀얼 카밍 오일 & 바운싱 크림   50ml     73000.0  4.32
#
# ...

# %%
#좋은/나쁜성분 리스트 생성
good_oily = '글리콜린산/살리실산/난 옥시놀-9/녹차/위치 하젤/레몬/캄파/멘톨클로로필/알라토인/티트리/감초/징크 옥사이트/칼렌 듈라 추출물/설퍼/트리클로잔/티타늄 옥사이드'
bad_oily = '트리글리세라이드/팔마티산염/미리스틴산/스테아르산염/스테아린산/코코넛오일/시어버터/바세린/옥시벤존/메톡시시나메이트'
good_dry = '히아루론산/글리세린/프로필렌 글라이콜/1,3-부틸렌 글라이콘/소디움PCA/비타민E/비타민A/비타민C/콜레젠/엘라스틴/아보카도 오일/이브닝 프라임 로즈 오일/오트밀 단백질/콩 추출물/카모마일/오이/복숭아/해조 추출물/상백피 추출물/코직산/알부틴/포토씨 추출물/베타카로틴/시어버터/파일워트 추출물/비타민B 복합체/판테놀'
bad_dry = '알코올/진흙/계면활성제/멘톨/페퍼민트'
good_sensitive = '비타민K/비타민F/호스트체스트넛 추출물/카모마일/알로에/콘플라워/알란토인/해조 추출물/티타늄 옥사이트'
bad_sensitive = '알코올/계면활성제/멘톨/페퍼민트/유칼립투스/아로마오일/고농도 과일산(AHA,BHA)/오렌지/딸기/레몬/레티놀/옥시벤존/메톡시 시나메이트'
good_complex = ''
bad_complex = bad_dry + bad_oily

# %%
good_oily_list = good_oily.split('/')
bad_oily_list = bad_oily.split('/')
good_dry_list = good_dry.split('/')
bad_dry_list = bad_dry.split('/')
good_sensitive_list = good_sensitive.split('/')
bad_sensitive_list = bad_sensitive.split('/')
good_complex_list = []
bad_complex_list = bad_complex.split('/')

# %%
#태그 가중치 포함 유사도 점수 계산
df_result['new_result'] = df_result['review_result']+(df_result['product_type_result']*0.05)
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#피해야할 성분이 있는 행 삭제
del_list = '|'.join(good_oily_list) #피부타입 입력값에따른 bad리스트
df_result['del'] = df_result['ingredient'].str.contains(del_list)
del_index = df_result[df_result['del']==True].index
df_result.drop(del_index, axis=0, inplace=True)
df_result.drop(['del'], axis=1, inplace=True)
df_result
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       Unnamed: 0 brand                        name bottle  price_num  star  \
# 7114      7114.0  이자녹스  에이지 포커스 프라임 더블 이펙트 아이포올 크림  50ml     85000.0  4.12
# ...

# %%
#겹치는 리뷰 갯수 센 후 열 추가
num_count_dict = df_result['name'].value_counts().to_dict()
df_result['num_count'] = df_result['name'].apply(lambda x : num_count_dict[x])

#겹치는 행 삭제
df_result = df_result.drop_duplicates(['name'])

#겹치는 리뷰 갯수 스케일링 후 가산점
df_result['num_count_score'] = min_max_sc.fit_transform(df_result[['price_num']])
df_result['new_result'] = df_result.apply(lambda x : x['new_result']+( 0.01*x['num_count']), axis=1)
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# ...

# %%
min_max_sc = MinMaxScaler()

# %%
df_result
# Out:
#       Unnamed: 0 brand                        name bottle  price_num  star  \
# 7114      7114.0  이자녹스  에이지 포커스 프라임 더블 이펙트 아이포올 크림  50ml     85000.0  4.12
# 690        690.0    미샤           수퍼 아쿠아 울트라 히알론 크림  70ml     28000.0  4.25
# 7331      7331.0    미샤          아텔로콜라겐500 파워풀럼핑 크림  40ml     34000.0  4.09
# 3773      3773.0   유세린               볼륨 리프팅 나이트 크림  50ml     52000.0  4.17
# 1603      1603.0   락토덤                피부에 유익한 생보습제  75ml     28000.0  4.29
# ...          ...   ...                         ...    ...        ...   ...
# 988        988.0  스킨푸드               캐롯 카로틴 릴리프 크림  50ml     30000.0  4.26
# 1128      1128.0   일리윤             세라마이드 더마 페이셜 크림  80ml     24000.0  4.46
# 1166      1166.0  에스트라                아토베리어 365 크림  80ml     28000.0  4.35
# 1285      1285.0   유세린               우레아 리페어 리치 크림  50ml     35000.0  4.35
# 1349      1349.0  제로이드                  인텐시브 크림 엠디  80ml     35000.0  4.40
#
#                                            product_info  \
# ...

# %%
def weight_sum (df_result,question_1,question_2,min_max_sc):

    #가격이 중요할 경우 가중치 부여
    if question_1 == 'q1_price' :
        df_result['price_num_score'] = min_max_sc.fit_transform(df_result[['price_num']])
        df_result['new_result'] = df_result.apply(lambda x : x['new_result']+( 0.01*(1- x['price_num_score'])), axis=1)

        #성분이 중요할 경우 가중치 부여
    if question_2 == 'q2_ingre':
        df_result['danger_num_score'] = min_max_sc.fit_transform(df_result[['danger_num']])
        df_result['new_result'] = df_result.apply(lambda x : x['new_result']+( 0.01*(1-x['danger_num_score'])), axis=1)

    df_result.sort_values(by='new_result',ascending=False,inplace=True)
    df_result_final = df_result

    return df_result_final

# %%
#추천성분 가산점
good_list = '|'.join(good_oily_list) #피부타입 입력값에따른 good리스트
df_result['good'] = df_result['ingredient'].str.contains(good_list)
df_result['new_result'] = df_result.apply(lambda x : x['new_result']+( 0.01*x['good']), axis=1)

#감성분석 가산점
df_result['new_result'] = df_result.apply(lambda x : x['new_result']+( 0.01*x['sentiment']), axis=1)
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# ...

# %%
df_result.sort_values(by='new_result',ascending=False,inplace=True)
df_result
# Out:
# C:\Users\LeeSeula\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Unnamed: 0   brand                      name bottle  price_num  star  \
# 1021      1021.0     시메스          노르딕 버치 딥 모이스처 크림  50ml     28000.0  4.66
# 233        233.0      딸로           청자몽 맑은 피부 진정 크림  50ml     46000.0  4.49
# 523        523.0    프리메라         알파인 베리 워터리 수딩 젤크림  50ml     39000.0  4.54
# 402        402.0     웰스킨          타임스탑 에너자이징 아쿠아크림  50ml     24000.0  4.39
# 277        277.0     코스톡              톡톡 수딩 아쿠아 크림  70ml     28000.0  4.43
# ...          ...     ...                       ...    ...        ...   ...
# 6483      6483.0     설화수                 자음생크림 소프트  60ml    270000.0  4.63
# ...
